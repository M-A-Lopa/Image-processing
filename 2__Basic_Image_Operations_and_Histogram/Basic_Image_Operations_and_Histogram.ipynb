# %%
import numpy as np
from skimage import io, color, exposure, img_as_float
import matplotlib.pyplot as plt

# %%
import sys
print(sys.executable)
# Out:
# c:\Users\ASUS\AppData\Local\Programs\Python\Python310\python.exe

# %%
# !{sys.executable} -m pip install numpy matplotlib scikit-image

# %% [markdown]
# #Problem 1

# %%
# Load the "cat.png" image
I = io.imread("cat.png")

# Normalize the image
I =  img_as_float(I)

# # Calculate the height and the width of the image 
height = I.shape[0]
width = I.shape[1]

print("Height of the image - ", height)
print("Width of the image - ", width)
# Out:
# Height of the image -  679
# Width of the image -  647

# %%
plt.figure(figsize=(3, 3))
plt.imshow(I)
plt.axis("off")
# Out:
# (np.float64(-0.5), np.float64(646.5), np.float64(678.5), np.float64(-0.5))

# %%
fig, axes = plt.subplots(1, 5, figsize=(20, 5))

# The image provided is an RGBA image.
# You have to plot the G,B and A channels.
# Plotting of the image and the R channel has been shown.
# Set the cmaps for individual channels to 'gray'

# RGB image
axes[0].imshow(I)
axes[0].axis("off")
axes[0].set_title("RGB image")

# Red channel
axes[1].imshow(I[:, :, 0], cmap="gray")
axes[1].axis("off")
axes[1].set_title("Red")

# Green channel
axes[2].imshow(I[:, :, 1], cmap="gray")
axes[2].axis("off")
axes[2].set_title("Green")

# Blue channel
axes[3].imshow(I[:, :, 2], cmap="gray")
axes[3].axis("off")
axes[3].set_title("Blue")

# Alpha channel
axes[4].imshow(I[:, :, 3], cmap="gray")
axes[4].axis("off")
axes[4].set_title("Alpha")
# Out:
# Text(0.5, 1.0, 'Alpha')

# %% [markdown]
# # Problem 2

# %%
# Flip the image against the x-axis
I_flipped = I[::-1, :, :]

plt.imshow(I_flipped)
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(646.5), np.float64(678.5), np.float64(-0.5))

# %% [markdown]
# #Problem 3

# %% [markdown]
# Run the next cell to convert the image to grayscale.

# %%
# Drop the alpha channel by slicing
# skimage channels occupy the last index

I = I[:, :, :3]
I = color.rgb2gray(I)
plt.imshow(I, cmap = 'gray')
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(646.5), np.float64(678.5), np.float64(-0.5))

# %% [markdown]
# Now calculate the PDF for the grayscale image

# %%
# Calculate the PDF for the image
hist, bins_hist = exposure.histogram(I, nbins=256, normalize = True)

plt.plot(bins_hist, hist)
plt.xlabel("Pixel values")
plt.title('Probability Density Function')
plt.ylabel("Percentage")
# Out:
# Text(0, 0.5, 'Percentage')
